# %% [markdown]
# <a href="https://colab.research.google.com/github/mbexhrs3/Urban_Data_Analysis/blob/main/Urban_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/mbexhrs3/Urban_Data_Analysis/main/Mean_Population_Exposure_to_PM25_by%20_Country_2015_2019.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#           Country Subnational_Regions     Data_Units  ...  Y2018  Y2019  ObjectId
# 0  Czech Republic           Northwest  Micrograms/m3  ...   15.1   14.9         1
# 1  Czech Republic           Northeast  Micrograms/m3  ...   16.2   15.9         2
# 2  Czech Republic           Southeast  Micrograms/m3  ...   16.2   16.0         3
# 3  Czech Republic     Central Moravia  Micrograms/m3  ...   19.7   19.6         4
# 4         Denmark                 NaN  Micrograms/m3  ...    9.9    9.8         5
#
# [5 rows x 9 columns]

# %%
Canada_data = df[df['Country']=='Canada']
Canada_data
# Out:
#    Country          Subnational_Regions     Data_Units  ...  Y2018  Y2019  ObjectId
# 74  Canada                          NaN  Micrograms/m3  ...    7.1    7.1        75
# 75  Canada                     Manitoba  Micrograms/m3  ...    5.7    5.7        76
# 76  Canada    Newfoundland and Labrador  Micrograms/m3  ...    4.5    4.5        77
# 77  Canada         Prince Edward Island  Micrograms/m3  ...    4.1    4.0        78
# 78  Canada        Northwest Territories  Micrograms/m3  ...    6.9    7.0        79
# 79  Canada                 Saskatchewan  Micrograms/m3  ...    7.7    7.8        80
# 80  Canada                      Alberta  Micrograms/m3  ...    7.3    7.3        81
# 81  Canada             British Columbia  Micrograms/m3  ...    7.0    7.4        82
# 82  Canada                        Yukon  Micrograms/m3  ...    4.5    4.5        83
# 83  Canada                      Nunavut  Micrograms/m3  ...    3.6    3.7        84
# ...

# %%
Canada_data = Canada_data[1:] #remove national average data
Canada_data
# Out:
#    Country          Subnational_Regions     Data_Units  ...  Y2018  Y2019  ObjectId
# 75  Canada                     Manitoba  Micrograms/m3  ...    5.7    5.7        76
# 76  Canada    Newfoundland and Labrador  Micrograms/m3  ...    4.5    4.5        77
# 77  Canada         Prince Edward Island  Micrograms/m3  ...    4.1    4.0        78
# 78  Canada        Northwest Territories  Micrograms/m3  ...    6.9    7.0        79
# 79  Canada                 Saskatchewan  Micrograms/m3  ...    7.7    7.8        80
# 80  Canada                      Alberta  Micrograms/m3  ...    7.3    7.3        81
# 81  Canada             British Columbia  Micrograms/m3  ...    7.0    7.4        82
# 82  Canada                        Yukon  Micrograms/m3  ...    4.5    4.5        83
# 83  Canada                      Nunavut  Micrograms/m3  ...    3.6    3.7        84
# 84  Canada                  Nova Scotia  Micrograms/m3  ...    5.1    5.1        85
# ...

# %%
column = ['Provinces', 'Units', 2015, 2016,2017,2018,2019,'ObjectId']

# %%
Canada_data.rename(columns={'Subnational_Regions':'Provinces','Data_Units':'Units','Y2015':'2015','Y2016':'2016',
'Y2017':'2017','Y2018':'2018','Y2019':'2019'},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Canada_data
# Out:
#    Country                    Provinces          Units  ...  2018  2019  ObjectId
# 75  Canada                     Manitoba  Micrograms/m3  ...   5.7   5.7        76
# 76  Canada    Newfoundland and Labrador  Micrograms/m3  ...   4.5   4.5        77
# 77  Canada         Prince Edward Island  Micrograms/m3  ...   4.1   4.0        78
# 78  Canada        Northwest Territories  Micrograms/m3  ...   6.9   7.0        79
# 79  Canada                 Saskatchewan  Micrograms/m3  ...   7.7   7.8        80
# 80  Canada                      Alberta  Micrograms/m3  ...   7.3   7.3        81
# 81  Canada             British Columbia  Micrograms/m3  ...   7.0   7.4        82
# 82  Canada                        Yukon  Micrograms/m3  ...   4.5   4.5        83
# 83  Canada                      Nunavut  Micrograms/m3  ...   3.6   3.7        84
# 84  Canada                  Nova Scotia  Micrograms/m3  ...   5.1   5.1        85
# ...

# %%
year = ['2015','2016','2017','2018','2019']
Canada_data[year]
# Out:
#     2015  2016  2017  2018  2019
# 75   6.5   4.6   5.9   5.7   5.7
# 76   4.7   4.1   4.6   4.5   4.5
# 77   4.6   3.7   4.3   4.1   4.0
# 78   6.6   6.2   6.8   6.9   7.0
# 79   8.2   6.5   7.6   7.7   7.8
# 80   7.4   6.0   7.7   7.3   7.3
# 81   6.2   5.4   7.5   7.0   7.4
# 82   4.6   4.4   4.1   4.5   4.5
# 83   3.4   3.2   3.7   3.6   3.7
# 84   5.6   4.5   5.2   5.1   5.1
# 85   5.5   4.8   5.3   5.2   5.2
# 86   7.8   7.0   7.8   7.6   7.5
# 87   7.7   6.5   7.3   7.2   7.1

# %%
plt.bar(Canada_data.Provinces,Canada_data['2016'])
# Out:
# <BarContainer object of 13 artists>
